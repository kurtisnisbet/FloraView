# %%
# specify relative path

from pathlib import Path("../original dataset")
df = pd.read_csv(data_dir/"train.csv")

data_dir = Path

# %%
# import train csv dataset for EDA

import pandas as pd

i2b_train_data = pd.read_csv("0 original dataset\train.csv")
